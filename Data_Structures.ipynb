# %% [markdown]
# <a href="https://colab.research.google.com/github/Chirag-R-Karanth/Python-DSA/blob/main/Data_Structures.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Stack

# %%
#Stack
class stack:
    top = -1
    arr = []
    #def __init__(self):

    def push(top):
        top += 1
        arr.append(top)
        #arr.append(a)

    def pop():
        top -= 1
        print(arr[top])

    def main():
        obj = stack()
        obj.push(10)
        obj.pop()

if "__name__" == "__main__":
    main()

# %%
def check(str):
    open = "[{("
    close = ")}]"
    stack = []
    for char in str:
        if char in open:
            stack.append(char)
        elif char in close:
            if len(stack) == 0:
                return False
            if open.index(stack.pop()) != close.index(char):
                return False
    return len(stack) == 0

# %%
"""def check(str):
    flag = 0
    for i in range (len(str)):
        a = str%10
        if(str[a] == str[i]):
            continue
    return True
"""
str = input ("inp paranthesis")
print("valid" if check(str) else "invalid")

# %% [markdown]
# Stack unit <br> Higher precidence given to user defined than built in function

# %%
stack = []

def push(stack,item):
    stack.append(item)
    print(stack)

def pop(stack):
    try:
        print(stack.pop())
    except:
        return 0
    return "no" if is_empty(stack) == True else "Yes"

def is_empty(stack):
    try:
        return True if len(stack) == 0 else False
    except:
        return 0

stack=[]
print(is_empty(stack))

push(stack,6)
push(stack,7)
push(stack,8)
push(stack,9)
push(stack,10)
push(stack,11)
pop(stack)
pop(stack)
pop(stack)
pop(stack)
pop(stack)
pop(stack)
pop(stack)
pop(stack)

# %%
def is_empty(stack):
    return True if len(stack) == 0 else False

stack=[]
print(is_empty(stack))

def pop(stack):
    return "no" if is_empty(stack) == True else "Yes"

print(pop(stack))

# %%
stack = []

# Push items
stack.append("Task A")
stack.append("Task B")
stack.append("Task C")

print(f"Current Stack: {stack}") # ['Task A', 'Task B', 'Task C']

# Pop item (LIFO)
top_item = stack.pop()
print(f"Popped: {top_item}")    # 'Task C'
print(f"Remaining: {stack}")    # ['Task A', 'Task B']

# %% [markdown]
# # Queues

# %%
def josef_seq(n, k):
    s = []
    # Create the circle of people
    q = [i for i in range(1, n + 1)]
    j = 1

    while len(q) > 0:
        # Pop from the FRONT to maintain order
        item = q.pop(0)
        if j % k == 0:
            s.append(item)
        else:
            # Put them back at the end of the line
            q.append(item)
        j += 1
    return s

n = int(input("People: "))
k = int(input("Skipped: "))
print(josef_seq(n, k))

# %%
class Queue:
    def __init__(self):
        self.queue = []

    def is_empty(self):
        return True if len(self.queue) == 0 else False

    def enqueue(self,item):
        self.queue.append(item)
        print(self.queue)

    def dequeue(self):
        return None if self.is_empty() else self.queue.pop(0)

# %%
Q = Queue()
#Q.queue = []
Q.is_empty()
Q.enqueue(10)
Q.enqueue(20)
Q.enqueue(30)
Q.dequeue()
Q.dequeue()
Q.dequeue()
print(Q.dequeue())

# %%
from collections import deque

queue = deque()
# Enqueue items
queue.append("User 1")
queue.append("User 2")
queue.append("User 3")

print(f"Current Queue: {list(queue)}") # ['User 1', 'User 2', 'User 3']

# Dequeue item (FIFO)
first_user = queue.popleft()
print(f"Served: {first_user}")         # 'User 1'
print(f"Remaining: {list(queue)}")     # ['User 2', 'User 3']

# %%
class Dequeue:
    def __init__(self):
        self.queue = [20,30,55,66,77]

    def add_last(self,item):
        self.queue.append(item)
        # print(self.queue)

    def add_first(self,item):#Check for errors please
        # # for i in range (0,len(self.queue)-1):
        #     #print(i)
        #     #print(self.queue[i])
        #     for j in range (len(self.queue)-1):
        #         print(j)
        #         self.queue[j]=self.queue[j+1]
        #     # print(self.queue[i])
        #     # print(self.queue[i+1])

        # self.queue[0]=item
        self.queue = [item]+self.queue
        print(self.queue)


    def remove_last(self):
        print(self.queue.pop(0))

    def remove_first(self):#Check plz
        for i in range (len(self.queue)-1):
            self.queue[i-1]=self.queue[i]
        print(self.queue)

DQ = Dequeue()
DQ.add_first(10)
#print(DQ.add_last(20))
DQ.remove_first()

# %% [markdown]
# # Sequencial Search

# %%
from random import randint

def do_exp(floor,breaking):
    return floor >= breaking

def find_height(height,breaking):
    for i in range (1,height+1):
        if do_exp(i,breaking):
            return i-1
    return height

height = int(input("Input num of floors:"))
breaking = randint(1,height)
floor = find_height(height,breaking)
print("your egg is safe till {}".format(floor))

# %%
number_list = [33,25,12,69,67,35,20]

largest = number_list[0]
# print(largest)

for i in range (len(number_list)-1):
    if number_list[i]>largest:
        largest = number_list[i]

print(largest)

# %%
def word_count(inp,search):
    len(inp)
    count = 0
    for i in inp:
        if(i == search):
            count+= 1
    return count

# %%
inp = input("Enter the word bother").split()
search= input("enter the word plz")

count = word_count(inp,search)
print(search,inp)
print(count)

# %% [markdown]
# *   #### Binary Search

# %%
def safe_height(height,breaking):
    return breaking-1

height = int(input("Enter num of floors"))
breaking = int(input("First breaking floor:"))
floor = safe_height(height,breaking)
print(f"your Eggs are safe till {floor}th floor")

# %%
def Binary_sort(nums,x):
    low ,high ,mid = 0
    for i in nums:
        mid = len(nums)/2
        if mid == nums[i]:
            return mid
        elif mid >= nums[i]:
            mid = i+1
            continue
        elif mid<=nums[i]:
            mid = i-1
            continue

# %%
def search_pos(nums,x):
    for i in nums:
        if(x<nums[i]):
            return i

# %%
nums = [i for i in range(10,81,10)]
print(nums)
x= int(input("Num to insert"))
pos = search_pos(nums,x)
print(f"{x} must go in {pos}")
nums.insert(pos,x)
print(nums)

# %% [markdown]
# # Hash Table and Hash Function

# %%
1113%8

# %%
def roman_to_binary(s: str) -> str:
    # 1. Hash function (Dictionary mapping)
    map = {'I': 1, 'V': 5, 'X': 10, 'L': 50, 'C': 100, 'D': 500, 'M': 1000}

    # 2. Calculate decimal value
    total = 0
    for i in range(len(s)):
        # If current value < next value, subtract it
        if i + 1 < len(s) and map[s[i]] < map[s[i+1]]:
            total -= map[s[i]]
        else:
            total += map[s[i]]

    # 3. Convert decimal to binary
    print(total)
    return bin(total)[2:]

# Example: "IX" -> 9 -> "1001"
print(roman_to_binary("MCXI"))

# %%
ls

# %%
books=["The Little Princess",
        "The flying dutchman",
        "The CS50"]

for books in books:
    key = sum(map(ord,books))
    print(key,books)

# %%
class HashTable:
    def

# %% [markdown]
# # Sorting

# %% [markdown]
# *   Bubble Sort

# %%
arr = [1, 3, 2, 6, 5, 9, 8, 7]

def bubble_sort(arr):
    n = len(arr)
    for _ in range(n):
        for j in range(0, n - 1):
            if arr[j] > arr[j + 1]:
                arr[j], arr[j + 1] = arr[j + 1], arr[j]

bubble_sort(arr)
print(arr)

# %%
#Swapping 2 values
def swap(S,x,y):
    t = S[x]
    S[x] = S[y]
    S[y] = t

S = [10,20,30]
print(S)
swap(S,1,2)
print(S)

# %%
#pythonic swap
def swap1(S,x):
    S[x+1],S[x] = S[x],S[x+1]

S=[10,20]
print(S)
swap1(S,0)
print(S)

# %%
#Bubble sort
def bubble_sort(S):
    for j in range(len(S)-1):
        for i in range(len(S)-j-1):
            if(S[i] >= S[i+1]):
                S[i], S[i + 1] = S[i + 1], S[i]

S = [10,20,30,1,5,8,2,36]
bubble_sort(S)
print(S)

# %% [markdown]
# * Selection Sort

# %%
def selection_sort(S):
    n = len(S)
    for j in range(n - 1):
        min_idx = j
        for i in range(j + 1, n):
            if S[i] < S[min_idx]:
                min_idx = i
        S[j], S[min_idx] = S[min_idx], S[j]

S = [10,20,30,1,5,8,2,36]
selection_sort(S)
print(S)

# %% [markdown]
# *   Insertion Sort

# %%
def insertionSort(arr):
    for i in range(1, len(arr)):
        key = arr[i]
        j = i - 1

        while j >= 0 and key < arr[j]:
            arr[j + 1] = arr[j]
            j -= 1
        arr[j + 1] = key

S = [10,20,30,1,5,8,2,36]
insertionSort(S)
print(S)

# %%
#word finder
word1 = input("Enter a word")
word2 = input("enter another")

w1 = w2 = []

for i in range(len(word1)):
    w1.append(word1[i])

for i in range(len(word2)):
    w2.append(word2[i])

def sorting():
    n1 = len(word1)
    n2 = len(word2)

    for i in range(n1-1):
        midindex1 = i
        for j in range ()

# %% [markdown]
# * Merge Sort

# %%
def merge_sort(S):
    n = len(S)
    mid = n//2
    new = []
    if mid > 2:
        mid = n//2
    else:
        if S[mid]<S[mid+1]:
            S[mid],S[mid+1] = S[mid+1],S[mid]
    new.append(mid)
    new.append(mid+1)
    del S[:2]
    return merge_sort(S)

S = [10,20,30,1,5,8,2,36]
merge_sort(S)

# %%
def merge(S,L,R):
    k=0
    while len(L)>0 and len(R)>0:
        if L[0] <= R[0]:
            S[k]=L.pop(0)

        else:
            S[k] = R.pop(0)
        k += 1

    while len(L) != 0:
        S[k] = L.pop(0)
        k += 1
    while len(R) != 0:
        S[k] = R.pop(0)
        k += 1

def mergesort1(S):
    n = len(S)
    if n>1:
        print(S)
        mid =n//2
        L,R = S[:mid],S[mid:]
        mergesort1(L)
        mergesort1(R)
        merge(S,L,R)


S = [10,20,30,1,5,8,2,36]
mergesort1(S)
print(S)

# %%
def mergesort1(S):
    n = len(S)
    if n>1:
        print(S)
        mid =n//2
        low,high = S[:mid],S[mid:]
        mergesort1(S,low,mid)
        mergesort1(S,mid,high)
        merge(S,low,mid,high)


S = [10,20,30,1,5,8,2,36]
mergesort1(S)
print(S)

# %% [markdown]
# * Quick sort

# %%
def quicksort(arr):
    if len(arr) <= 1:
        return arr
    pivot = arr[len(arr) // 2]
    left = [x for x in arr if x < pivot]
    middle = [x for x in arr if x == pivot]
    right = [x for x in arr if x > pivot]
    return quicksort(left) + middle + quicksort(right)

# Example usage:
S = [10, 20, 30, 1, 5, 8, 2, 36]
print(f"Original list: {S}")
sorted_S = quicksort(S)
print(f"Sorted list: {sorted_S}")

# %%
def partition(S, low, high):
  pivot_value = S[low] # Store the pivot value
  left, right = low + 1, high # Pointers start just after pivot and at the end

  while True: # Keep looping until pointers cross
    # Move left pointer past elements <= pivot_value
    while left <= high and S[left] <= pivot_value:
      left += 1
    # Move right pointer past elements >= pivot_value
    # right >= low + 1 ensures we don't compare S[low] with itself if right moves to low
    while right >= low + 1 and S[right] > pivot_value: # Use '>' to handle duplicates correctly
      right -= 1

    if left >= right: # Pointers have crossed or met
      break # Exit the loop

    # If pointers haven't crossed, swap elements
    S[left], S[right] = S[right], S[left]

  # After the loop, 'right' is the correct position for the pivot
  # Swap the pivot element (originally at S[low]) with S[right]
  S[low], S[right] = S[right], S[low]
  return right # Return the pivot's final index


def quicksort(S,low,high):
  if low < high:
    print(S)
    pivotpoint = partition(S,low,high)
    quicksort(S,low,pivotpoint-1)
    quicksort(S,pivotpoint+1,high)

S = [10,20,30,1,5,8,2,36]
quicksort(S,0,len(S)-1)
print(S)
