# %%
#Stack
class stack:
    top = -1
    arr = []
    #def __init__(self):
       
    def push(top):
        top += 1
        arr.append(top)
        #arr.append(a)  

    def pop():
        top -= 1
        print(arr[top])

    def main():
        obj = stack()
        obj.push(10)
        obj.pop()

if "__name__" == "__main__":
    main()

# %%
def check(str):
    open = "[{("
    close = ")}]"
    stack = []
    for char in str:
        if char in open:
            stack.append(char)
        elif char in close:
            if len(stack) == 0:
                return False
            if open.index(stack.pop()) != close.index(char):
                return False
    return len(stack) == 0
# Out:
#   Cell In[7], line 4
#     stack[]
#           ^
# SyntaxError: invalid syntax

# %%
"""def check(str):
    flag = 0
    for i in range (len(str)):
        a = str%10
        if(str[a] == str[i]):
            continue
    return True
"""
str = input ("inp paranthesis")
print("valid" if check(str) else "invalid")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 10
#       7             continue
#       9 str = input ("inp paranthesis")
# ---> 10 print("valid" if check(str) else "invalid")
#
# Cell In[6], line 4, in check(str)
#       2 flag = 0
#       3 for i in range (len(str)):
# ----> 4     a = str%10
#       5     if(str[a] == str[i]):
#       6         flag += 1
#
# TypeError: not all arguments converted during string formatting
